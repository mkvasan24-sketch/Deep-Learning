# %% [markdown]
# # Importing Libraries

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %% [markdown]
# # Data Collection

# %%
train_dir =r"/content/drive/MyDrive/Deep Learning/CNN_image classification/train_data"
val_dir = r"/content/drive/MyDrive/Deep Learning/CNN_image classification/val_data"
test_dir = r"/content/drive/MyDrive/Deep Learning/CNN_image classification/test_data"

# %% [markdown]
# ## Setting Image size and Batch size

# %%
IMG_SIZE = (224, 224)
BATCH_SIZE = 32

# %% [markdown]
# ## Loading training dataset

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(directory=train_dir,image_size=IMG_SIZE,batch_size=BATCH_SIZE,shuffle=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 train_ds = tf.keras.utils.image_dataset_from_directory(directory=train_dir,image_size=IMG_SIZE,batch_size=BATCH_SIZE,shuffle=True)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\utils\image_dataset_utils.py:265, in image_dataset_from_directory(directory, labels, label_mode, class_names, color_mode, batch_size, image_size, shuffle, seed, validation_split, subset, interpolation, follow_links, crop_to_aspect_ratio, pad_to_aspect_ratio, data_format, format, verbose)
#     263 if seed is None:
#     264     seed = np.random.randint(1e6)
# --> 265 image_paths, labels, class_names = dataset_utils.index_directory(
#     266     directory,
#     267     labels,
#     268     formats=ALLOWLIST_FORMATS,
#     269     class_names=class_names,
#     270     shuffle=shuffle,
# ...

# %% [markdown]
# ## Loading Test Dataset

# %%
test_ds = tf.keras.utils.image_dataset_from_directory(directory=test_dir,image_size=IMG_SIZE,batch_size=BATCH_SIZE)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 test_ds = tf.keras.utils.image_dataset_from_directory(directory=test_dir,image_size=IMG_SIZE,batch_size=BATCH_SIZE)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\utils\image_dataset_utils.py:265, in image_dataset_from_directory(directory, labels, label_mode, class_names, color_mode, batch_size, image_size, shuffle, seed, validation_split, subset, interpolation, follow_links, crop_to_aspect_ratio, pad_to_aspect_ratio, data_format, format, verbose)
#     263 if seed is None:
#     264     seed = np.random.randint(1e6)
# --> 265 image_paths, labels, class_names = dataset_utils.index_directory(
#     266     directory,
#     267     labels,
#     268     formats=ALLOWLIST_FORMATS,
#     269     class_names=class_names,
#     270     shuffle=shuffle,
# ...

# %% [markdown]
# ## Loading Valdition Dataset

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(directory=val_dir,image_size=IMG_SIZE,batch_size=BATCH_SIZE)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 val_ds = tf.keras.utils.image_dataset_from_directory(directory=val_dir,image_size=IMG_SIZE,batch_size=BATCH_SIZE)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\utils\image_dataset_utils.py:265, in image_dataset_from_directory(directory, labels, label_mode, class_names, color_mode, batch_size, image_size, shuffle, seed, validation_split, subset, interpolation, follow_links, crop_to_aspect_ratio, pad_to_aspect_ratio, data_format, format, verbose)
#     263 if seed is None:
#     264     seed = np.random.randint(1e6)
# --> 265 image_paths, labels, class_names = dataset_utils.index_directory(
#     266     directory,
#     267     labels,
#     268     formats=ALLOWLIST_FORMATS,
#     269     class_names=class_names,
#     270     shuffle=shuffle,
#     271     seed=seed,
# ...

# %% [markdown]
# ## Class Names

# %%
class_names = train_ds.class_names

print(class_names)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 class_names = train_ds.class_names
#       3 print(class_names)
#
# NameError: name 'train_ds' is not defined

# %% [markdown]
# # Data Understanding

# %%
for images, labels in train_ds.take(1):
    print("Image shape:", images.shape)
    print("Label shape:", labels.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 for images, labels in train_ds.take(1):
#       2     print("Image shape:", images.shape)
#       3     print("Label shape:", labels.shape)
#
# NameError: name 'train_ds' is not defined

# %% [markdown]
# ## To Improve data

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.prefetch(buffer_size=AUTOTUNE)
test_ds = test_ds.prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# # Model Building

# %%
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
])

# %%
model = keras.Sequential([

    layers.Input(shape=(224, 224, 3)),

    # Data augmentation
    data_augmentation,

    # Normalize pixels
    layers.Rescaling(1./255),

    # Convolution Block 1
    layers.Conv2D(32, (3, 3), activation="relu"),
    layers.MaxPooling2D(),

    # Convolution Block 2
    layers.Conv2D(64, (3, 3), activation="relu"),
    layers.MaxPooling2D(),

    # Convolution Block 3
    layers.Conv2D(128, (3, 3), activation="relu"),
    layers.MaxPooling2D(),

    # Convert feature maps into vector
    layers.Flatten(),

    # Fully connected layer
    layers.Dense(128, activation="relu"),

    # Prevent overfitting
    layers.Dropout(0.5),

    # Five-class output
    layers.Dense(5, activation="softmax")
])

# %%
model.summary()

# %%
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# %% [markdown]
# # Model Training

# %%
history = model.fit(train_ds,validation_data=val_ds,epochs=30,)

# %% [markdown]
# # Model Evalution

# %%
plt.figure(figsize=(8, 5))

plt.plot(history.history["accuracy"], label="Training Accuracy")
plt.plot(history.history["val_accuracy"], label="Validation Accuracy")

plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Training vs Validation Accuracy")
plt.legend()

plt.show()

# %%
test_loss, test_accuracy = model.evaluate(test_ds)

print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)

# %% [markdown]
# # Prediction new image

# %%
img = tf.keras.utils.load_img(
   r"/content/drive/MyDrive/Deep Learning/CNN_image classification/val_data/dhanush/WhatsApp Image 2026-09-17 at 10.33.24 PM (9).jpeg",
    target_size=IMG_SIZE
)

img_array = tf.keras.utils.img_to_array(img)

img_array = tf.expand_dims(img_array, 0)

# %%
predictions = model.predict(img_array)

predicted_index = np.argmax(predictions[0])

predicted_class = class_names[predicted_index]

confidence = predictions[0][predicted_index]

print("Predicted Class:", predicted_class)
print("Confidence:", confidence)
